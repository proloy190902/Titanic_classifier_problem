# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('gender_submission.csv')

# %%
df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
trainset_copy=df_train.copy()

# %%
df_train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.shape # returns the number of rows and columns
# Out:
# (891, 12)

# %%
df_train.info() # gives insights such as column_label, non_null_values, column_datatypes etc..
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_train.describe() # computes and display the statistical summary of our data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # DATA CLEANING

# %%
# finding unique elements in the column 'Pclass' 
df_train['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
# finding unique elements in the column 'Age' 
df_train['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# finding unique elements in the column 'Survived' 
df_train['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# finding unique elements in the column 'Embarked' 
df_train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# check for duplicate entries
df_train.duplicated().sum()
# Out:
# 0

# %%
# drop unwanted columns
df_train.drop(['Name','Ticket','Fare','Cabin'],axis=1,inplace=True)
df_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %%
df_train.info() # after dropping unwanted columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Embarked     889 non-null    object
# dtypes: float64(1), int64(5), object(2)
# memory usage: 55.8+ KB

# %%
# checking for total null values
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# dtype: int64

# %%
# filling missing values for the column 'Age'
df_train['Age']=df_train['Age'].fillna(value=df_train['Age'].mean())

# %%
df_train["Embarked"].fillna( method ='ffill',limit=1,inplace = True)

# %%
df_train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Embarked       0
# dtype: int64

# %%
# check for outliers
df_train.skew()
# Out:
# C:\Users\proloy\AppData\Local\Temp\ipykernel_6196\4259773610.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_train.skew()
# PassengerId    0.000000
# Survived       0.478523
# Pclass        -0.630548
# Age            0.434488
# SibSp          3.695352
# Parch          2.749117
# dtype: float64

# %%
# get_dummies is used to convert categorical data into dummy or indicator variable
S=df_train.Sex
dummy=pd.get_dummies(S)
dummy.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
df_train=pd.concat([dummy,df_train],axis=1)
df_train.head()
# Out:
#    female  male  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0       0     1            1         0       3    male  22.0      1      0
# 1       1     0            2         1       1  female  38.0      1      0
# 2       1     0            3         1       3  female  26.0      0      0
# 3       1     0            4         1       1  female  35.0      1      0
# 4       0     1            5         0       3    male  35.0      0      0
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
df_train.drop(['Sex'],axis=1,inplace=True)
df_train.head()
# Out:
#    female  male  PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked
# 0       0     1            1         0       3  22.0      1      0        S
# 1       1     0            2         1       1  38.0      1      0        C
# 2       1     0            3         1       3  26.0      0      0        S
# 3       1     0            4         1       1  35.0      1      0        S
# 4       0     1            5         0       3  35.0      0      0        S

# %%
E=df_train.Embarked
dummies=pd.get_dummies(E)
dummies.head()
# Out:
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
df_train.drop(['Embarked'],axis=1,inplace=True)

# %%
df_train=pd.concat([dummies,df_train],axis=1)
df_train.head()
# Out:
#    C  Q  S  female  male  PassengerId  Survived  Pclass   Age  SibSp  Parch
# 0  0  0  1       0     1            1         0       3  22.0      1      0
# 1  1  0  0       1     0            2         1       1  38.0      1      0
# 2  0  0  1       1     0            3         1       3  26.0      0      0
# 3  0  0  1       1     0            4         1       1  35.0      1      0
# 4  0  0  1       0     1            5         0       3  35.0      0      0

# %%
df_train.describe()
# Out:
#                 C           Q           S      female        male  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.189675    0.087542    0.722783    0.352413    0.647587
# std      0.392264    0.282787    0.447876    0.477990    0.477990
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    1.000000
# 75%      0.000000    0.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        PassengerId    Survived      Pclass         Age       SibSp       Parch
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.486592    0.836071   13.002015    1.102743    0.806057
# ...

# %% [markdown]
# # SURVIVED VS DIED

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Survived',data=df_train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# # SPLITTING THE DATA

# %%
X_train=df_train.drop(['Survived'],axis=1)

# %%
y_train=df_train.Survived

# %% [markdown]
# # TEST DATA ANALYSIS

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df_test.shape
# Out:
# (418, 11)

# %%
# checking for duplicates
df_test.duplicated().sum()
# Out:
# 0

# %%
# checking for null values
df_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# filling null values
mean=df_test['Age'].mean()
df_test=df_test.fillna(mean)

# %%
# dropping unwanted columns
df_test.drop(columns=['Name','Fare','Ticket','Cabin'],axis=1,inplace=True)
df_test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch Embarked
# 0          892       3    male  34.5      0      0        Q
# 1          893       3  female  47.0      1      0        S
# 2          894       2    male  62.0      0      0        Q
# 3          895       3    male  27.0      0      0        S
# 4          896       3  female  22.0      1      1        S

# %%
S1=df_test.Sex
dummy1=pd.get_dummies(S1)
dummy1.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       0     1
# 3       0     1
# 4       1     0

# %%
df_test=pd.concat([dummy1,df_test],axis=1)
df_test.head()
# Out:
#    female  male  PassengerId  Pclass     Sex   Age  SibSp  Parch Embarked
# 0       0     1          892       3    male  34.5      0      0        Q
# 1       1     0          893       3  female  47.0      1      0        S
# 2       0     1          894       2    male  62.0      0      0        Q
# 3       0     1          895       3    male  27.0      0      0        S
# 4       1     0          896       3  female  22.0      1      1        S

# %%
df_test.drop(['Sex'],axis=1,inplace=True)

# %%
E1=df_test.Embarked
dummy2=pd.get_dummies(E1)
dummy2.head()
# Out:
#    C  Q  S
# 0  0  1  0
# 1  0  0  1
# 2  0  1  0
# 3  0  0  1
# 4  0  0  1

# %%
df_test=pd.concat([dummy2,df_test],axis=1)

# %%
df_test.drop(['Embarked'],axis=1,inplace=True)

# %%
df_test.head()
# Out:
#    C  Q  S  female  male  PassengerId  Pclass   Age  SibSp  Parch
# 0  0  1  0       0     1          892       3  34.5      0      0
# 1  0  0  1       1     0          893       3  47.0      1      0
# 2  0  1  0       0     1          894       2  62.0      0      0
# 3  0  0  1       0     1          895       3  27.0      0      0
# 4  0  0  1       1     0          896       3  22.0      1      1

# %%
corr1=df_test.corr()

# %%
corr1
# Out:
#                     C         Q         S    female      male  PassengerId  \
# C            1.000000 -0.199786 -0.767375  0.033684 -0.033684    -0.027419
# Q           -0.199786  1.000000 -0.474962  0.115574 -0.115574    -0.035731
# S           -0.767375 -0.474962  1.000000 -0.105883  0.105883     0.048008
# female       0.033684  0.115574 -0.105883  1.000000 -1.000000    -0.023245
# male        -0.033684 -0.115574  0.105883 -1.000000  1.000000     0.023245
# PassengerId -0.027419 -0.035731  0.048008 -0.023245  0.023245     1.000000
# Pclass      -0.318543  0.252608  0.120783 -0.108615  0.108615    -0.026751
# Age          0.161612 -0.012719 -0.136822 -0.000011  0.000011    -0.030874
# SibSp       -0.016365 -0.098824  0.079367  0.099943 -0.099943     0.003818
# Parch       -0.005791 -0.132948  0.092201  0.159120 -0.159120     0.043080
#
#                Pclass       Age     SibSp     Parch
# C           -0.318543  0.161612 -0.016365 -0.005791
# ...

# %% [markdown]
# # PREDICTIVE MODEL

# %%
from sklearn.ensemble import RandomForestClassifier
features=['Pclass','female','male','SibSp','Parch']
X=pd.get_dummies(df_train[features])
y=df_train['Survived']

X_test=pd.get_dummies(df_test[features])
model=RandomForestClassifier(n_estimators=100,max_depth=3,random_state=2)
model.fit(X,y)
prediction = model.predict(X_test)
result=pd.DataFrame({'PassengerId':df_test.PassengerId,'Survived':prediction})

# %%
result.to_csv('submission.csv',index=False)

# %%
features=['Pclass','female','male','SibSp','Parch','Age','C','Q','S','PassengerId']
X=pd.get_dummies(df_train[features])
X
# Out:
#      Pclass  female  male  SibSp  Parch        Age  C  Q  S  PassengerId
# 0         3       0     1      1      0  22.000000  0  0  1            1
# 1         1       1     0      1      0  38.000000  1  0  0            2
# 2         3       1     0      0      0  26.000000  0  0  1            3
# 3         1       1     0      1      0  35.000000  0  0  1            4
# 4         3       0     1      0      0  35.000000  0  0  1            5
# ..      ...     ...   ...    ...    ...        ... .. .. ..          ...
# 886       2       0     1      0      0  27.000000  0  0  1          887
# 887       1       1     0      0      0  19.000000  0  0  1          888
# 888       3       1     0      1      2  29.699118  0  0  1          889
# 889       1       0     1      0      0  26.000000  1  0  0          890
# 890       3       0     1      0      0  32.000000  0  1  0          891
#
# [891 rows x 10 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
features=['Pclass','female','male','SibSp','Parch']
X=pd.get_dummies(df_train[features])
y=df_train['Survived']
X_test=pd.get_dummies(df_test[features])
model=KNeighborsClassifier(n_neighbors=100)
model.fit(X,y)
prediction1 = model.predict(X_test)
result=pd.DataFrame({'PassengerId':df_test.PassengerId,'Survived':prediction})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
result.to_csv('Proloy.csv',index=False)

# %%
relevant_features = ['Pclass', 'Age', 'SibSp', 'Parch',  'C','Q','S','female','male']

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# train_df[relevant_features] = scaler.fit_transform(train_df[relevant_features])
# test_df[relevant_features] = scaler.transform(test_df[relevant_features])

# %%
# Split the data into features (X) and labels (y)
X_train = df_train[relevant_features]
y_train = df_train['Survived']
X_test = df_test[relevant_features]

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=33)

# %%
#KNN Classifier
from sklearn.neighbors import KNeighborsClassifier
classifier=  KNeighborsClassifier(n_neighbors=100)
classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=100)

# %%
y_pred = classifier.predict(X_val)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
# Evaluate the fine-tuned model
accuracy = accuracy_score(y_val, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.6089385474860335
